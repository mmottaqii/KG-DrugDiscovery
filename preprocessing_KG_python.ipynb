# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # CCLE - gene expression dataset

# %%
df = pd.read_csv("/home/vmottaqi/kg/ccle_gene_expression/gene_attribute_matrix_standardized.txt", delimiter="\t", low_memory=False)
df
# Out:
#                #  #.1   CellLine          TT        TT.1           SNU503  \
# 0              #    #     Tissue  oesophagus  oesophagus  large intestine
# 1        GeneSym  NaN  GeneID/NA          na          na               na
# 2         CAMK1D   na      57118    0.732836    0.732836         0.131201
# 3      LOC283070   na     283070    0.799955    0.799955         0.209032
# 4        HSD17B6   na       8630    0.157019    0.157019        -0.015149
# ...          ...  ...        ...         ...         ...              ...
# 18043      FNIP2   na      57600   -0.443149   -0.443149        -0.440713
# 18044      HIPK2   na      28996   -0.395702   -0.395702        -0.014883
# 18045     CYP4V2   na     285440   -0.144131   -0.144131         0.056081
# 18046    FAM149A   na      25854    0.167679    0.167679         0.778482
# 18047     SORBS2   na       8470   -0.389852   -0.389852         0.126316
#
#                           BICR18     LUDLU1     KYSE140     KYSE180  ...  \
# ...
